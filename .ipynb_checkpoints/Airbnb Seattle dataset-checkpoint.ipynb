# %%
import pandas as pd

# %%
# Including listing id and the price and availability for that day
seattle_calendar_df = pd.read_csv("data/airbnb/seattle/calendar.csv")
seattle_calendar_df.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
seattle_calendar_df.columns.values
# Out:
# array(['listing_id', 'date', 'available', 'price'], dtype=object)

# %%
seattle_calendar_df.describe()
# Out:
#          listing_id
# count  1.393570e+06
# mean   5.550111e+06
# std    2.962274e+06
# min    3.335000e+03
# 25%    3.258213e+06
# 50%    6.118244e+06
# 75%    8.035212e+06
# max    1.034016e+07

# %%
# Including full descriptions and average review score
seattle_listings_df = pd.read_csv("data/airbnb/seattle/listings.csv")
seattle_listings_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  Queen Anne is a wonderful, truly functional vi...        ...
# 2  Upper Queen Anne is a charming neighborhood fu...        ...
# 3                                                NaN        ...
# 4  We are in the beautiful neighborhood of Queen ...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                10.0                f     NaN         WASHINGTON
# 2                10.0                f     NaN         WASHINGTON
# 3                 NaN                f     NaN         WASHINGTON
# 4                 9.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            moderate                              f
# 1                f              strict                              t
# 2                f              strict                              f
# 3                f            flexible                              f
# 4                f              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
seattle_listings_df.columns.values
# Out:
# array(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'square_feet', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value',
#        'requires_license', 'license', 'jurisdiction_names',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture',
#        'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype=object)

# %%
seattle_listings_df = seattle_listings_df[['id', 'description', 'neighborhood_overview', 'neighbourhood']]
seattle_listings_df
# Out:
#             id                                        description  \
# 0       241032  Make your self at home in this charming one-be...
# 1       953595  Chemically sensitive? We've removed the irrita...
# 2      3308979  New modern house built in 2013.  Spectacular s...
# 3      7421966  A charming apartment that sits atop Queen Anne...
# 4       278830  Cozy family craftman house in beautiful neighb...
# 5      5956968  We're renting out a small private unit of one ...
# 6      1909058  Enjoy a quiet stay in our comfortable 1915 Cra...
# 7       856550  Our tiny cabin is private , very quiet and com...
# 8      4948745  Nestled in the heart of the city, this space i...
# 9      2493658  Beautiful apartment in an extremely safe, quie...
# 10      175576  Queen Anne Hill is a charming neighborhood wit...
# 11     4454295  Beautifully furnished, cozy 1 bedroom mid cent...
# 12     3883392  Spacious apt in popular Seattle neighborhood. ...
# 13     8889257  Enjoy our amazing, updated & modern design cot...
# 14     5680462  Stunning Designsponge featured 6 bed, 3.75 bat...
# 15     8988178  This home is full of light, art and comfort. 5...
# 16     3245876  Master bedroom suite with 1/4 bath & kitchenet...
# 17     4933447  Beautiful private entrance garden suite overlo...
# 18     7735464  The second room in our spacious 2BR / 2 Bath a...
# 19     6291829  This  home built in 1909.  It has 5 bedrooms a...
# 20     9218403  This clean and comfortable one bedroom sits ri...
# 21     4125779  Relax in your own private finished basement sp...
# 22     8942678  Welcome to Seattle! Enjoy your stay in a  turn...
# 23    10106055  Greetings!  Our home is a beautiful, 1920's 4 ...
# 24     6362362  Enjoy Seattle from the ideally located Queen A...
# 25     3544550  Our home is very light and full of character a...
# 26     9025039  Our cozy little bungalow is the perfect place ...
# 27     3200646  Micro camper with queen size bed and seating f...
# 28     8859380  This three bedroom flat is your gorgeous retre...
# 25    Upper Queen Anne is a charming neighborhood fu...    Queen Anne
# 26    The Queen Anne neighborhood is one of the most...    Queen Anne
# 27    Interbay is right between downtown Seattle and...    Queen Anne
# 28    Located in the beautiful neighborhood of Queen...    Queen Anne
# 29    This is a really quiet neighborhood with plent...    Queen Anne
# ...                                                 ...           ...
# 3788  The Fremont neighborhood of Seattle is known a...       Fremont
# 3789  I love that I can walk 15 minutes into Fremont...       Fremont
# 3790  Very walkable, with lots of bike lanes and qui...       Fremont
# 3791  Our house is centrally located between Ballard...       Fremont
# 3792                                                NaN       Fremont
# 3793  Renowned restaurants, coffeshops and bars, the...       Fremont
# 3794  Fremont - The Center Of The Universe.  This ne...       Fremont
# 3795  Fremont is a unique, young neighborhood filled...           NaN
# 3796  FREMONT is such a fun neighborhood with lot's ...       Fremont
# 3797  Located at the top of Fremont neighborhood/up ...       Fremont
# 3798  I love everything about my neighborhood, Seatt...       Fremont
# 3799                                                NaN       Fremont
# 3800  Chelsea Station Inn is walking distance to the...       Fremont
# 3801  Fremont is centrally located within the city a...       Fremont
# 3802  I loved living here before we had 3 kids. The ...           NaN
# 3803  This house is central to any neighborhood you'...       Fremont
# 3804  Upper Fremont is a vibrant neighborhood that o...       Fremont
# 3805  One of the most fun neighborhoods in Seattle. ...       Fremont
# 3806                                                NaN       Fremont
# 3807  From the apartment it is an easy walk to the h...   Wallingford
# 3808  Fremont is wonderful; you will love it here. T...       Fremont
# 3809  This cottage apartment is located just a few b...       Fremont
# 3810  We love that Fremont is so centrally located t...       Fremont
# 3811  I am equidistant to Fremont and Wallingford an...       Fremont
# 3812  It's taken me a while to figure out why Fremon...       Fremont
# 3813  We're located near lots of family fun. Woodlan...       Fremont
# 3814  The neighborhood is a quiet oasis that is clos...   Portage Bay
# 3815                                                NaN           NaN
# 3816  Madison Park offers a peaceful slow pace upsca...           NaN
# 3817                                                NaN    Queen Anne
#
# [3818 rows x 4 columns]

# %%
seattle_listings_df.isnull()['neighbourhood'].mean()
# Out:
# 0.10895756940806706

# %%
seattle_listings_df = seattle_listings_df.dropna(subset=['neighbourhood'], axis=0)
seattle_listings_df
# Out:
#             id                                        description  \
# 0       241032  Make your self at home in this charming one-be...
# 1       953595  Chemically sensitive? We've removed the irrita...
# 2      3308979  New modern house built in 2013.  Spectacular s...
# 3      7421966  A charming apartment that sits atop Queen Anne...
# 4       278830  Cozy family craftman house in beautiful neighb...
# 5      5956968  We're renting out a small private unit of one ...
# 6      1909058  Enjoy a quiet stay in our comfortable 1915 Cra...
# 7       856550  Our tiny cabin is private , very quiet and com...
# 8      4948745  Nestled in the heart of the city, this space i...
# 9      2493658  Beautiful apartment in an extremely safe, quie...
# 10      175576  Queen Anne Hill is a charming neighborhood wit...
# 11     4454295  Beautifully furnished, cozy 1 bedroom mid cent...
# 13     8889257  Enjoy our amazing, updated & modern design cot...
# 14     5680462  Stunning Designsponge featured 6 bed, 3.75 bat...
# 16     3245876  Master bedroom suite with 1/4 bath & kitchenet...
# 17     4933447  Beautiful private entrance garden suite overlo...
# 18     7735464  The second room in our spacious 2BR / 2 Bath a...
# 13    Queen Anne hill became a popular spot for the ...    Queen Anne
# 14    Queen Anne is THE BEST and most desirable neig...    Queen Anne
# 16    Lower Queen Anne is amazing - you can walk to ...    Queen Anne
# 17    We are located in Upper Queen Anne in walking ...    Queen Anne
# 18                                                  NaN    Queen Anne
# 19    Upper Queen Anne is a charming neighborhood wi...    Queen Anne
# 21    Just a few minutes walk to many great restaura...    Queen Anne
# 22    Queen Anne is a wonderful mix of beautiful tre...    Queen Anne
# 23    Queen Anne is a lovely and venerable Seattle n...    Queen Anne
# 24                                                  NaN    Queen Anne
# 25    Upper Queen Anne is a charming neighborhood fu...    Queen Anne
# 26    The Queen Anne neighborhood is one of the most...    Queen Anne
# 27    Interbay is right between downtown Seattle and...    Queen Anne
# 28    Located in the beautiful neighborhood of Queen...    Queen Anne
# 29    This is a really quiet neighborhood with plent...    Queen Anne
# 30    Queen Anne is a wonderful, truly functional vi...    Queen Anne
# 31    The Queen Anne area is very much a walking com...    Queen Anne
# 32    My house is on the coveted West slope with the...    Queen Anne
# ...                                                 ...           ...
# 3784                                                NaN       Fremont
# 3785  This is my favorite location I have ever lived...       Fremont
# 3786                                                NaN       Fremont
# 3787  Fremont is one of Seattle's hottest neighborho...       Fremont
# 3788  The Fremont neighborhood of Seattle is known a...       Fremont
# 3789  I love that I can walk 15 minutes into Fremont...       Fremont
# 3790  Very walkable, with lots of bike lanes and qui...       Fremont
# 3791  Our house is centrally located between Ballard...       Fremont
# 3792                                                NaN       Fremont
# 3793  Renowned restaurants, coffeshops and bars, the...       Fremont
# 3794  Fremont - The Center Of The Universe.  This ne...       Fremont
# 3796  FREMONT is such a fun neighborhood with lot's ...       Fremont
# 3797  Located at the top of Fremont neighborhood/up ...       Fremont
# 3798  I love everything about my neighborhood, Seatt...       Fremont
# 3799                                                NaN       Fremont
# 3800  Chelsea Station Inn is walking distance to the...       Fremont
# 3801  Fremont is centrally located within the city a...       Fremont
# 3803  This house is central to any neighborhood you'...       Fremont
# 3804  Upper Fremont is a vibrant neighborhood that o...       Fremont
# 3805  One of the most fun neighborhoods in Seattle. ...       Fremont
# 3806                                                NaN       Fremont
# 3807  From the apartment it is an easy walk to the h...   Wallingford
# 3808  Fremont is wonderful; you will love it here. T...       Fremont
# 3809  This cottage apartment is located just a few b...       Fremont
# 3810  We love that Fremont is so centrally located t...       Fremont
# 3811  I am equidistant to Fremont and Wallingford an...       Fremont
# 3812  It's taken me a while to figure out why Fremon...       Fremont
# 3813  We're located near lots of family fun. Woodlan...       Fremont
# 3814  The neighborhood is a quiet oasis that is clos...   Portage Bay
# 3817                                                NaN    Queen Anne
#
# [3402 rows x 4 columns]

# %%
neighbourhood_list_count = seattle_listings_df.groupby(['neighbourhood']).size()
neighbourhood_list_count.sort_values(ascending=False)[:5]
# Out:
# neighbourhood
# Capitol Hill    351
# Ballard         213
# Belltown        204
# Minor           192
# Queen Anne      187
# dtype: int64

# %%
neighbourhood = seattle_listings_df['neighbourhood']
len(set(neighbourhood))
# Out:
# 81

# %%
# Including unique id for each reviewer and detailed comments
seattle_reviews_df = pd.read_csv("data/airbnb/seattle/reviews.csv")
seattle_reviews_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
